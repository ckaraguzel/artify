# %%
from google.colab import drive

# %%
import pandas as pd
import numpy as np
import os
import re

# %%
# Step 1: Mount Google Drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
painters_to_keep = [
    'claude monet', 'pierre auguste renoir', 'vincent van gogh',
    'paul cezanne', 'pablo picasso', 'georges braque',
    'salvador dali', 'rene magritte'
]

# %%
# Define the dataset path
dataset_path = '/content/drive/MyDrive/colab_data/wikiart_dataset'

# Initialize data storage
data = {'painting': [], 'normalized_painting': [], 'genre': []}

# Traverse through the directory structure
for root, _, files in os.walk(dataset_path):
    for filename in files:
        # Check if it's a file
        if os.path.isfile(os.path.join(root, filename)):
            # Get the genre as the subfolder name directly under `wikiart_dataset`
            genre = os.path.basename(os.path.normpath(root)).lower()

            # Append the original painting name
            data['painting'].append(filename)

            # Apply the regex function to normalize the painting name
            normalized_name = re.sub(r'[^a-zA-Z0-9]', ' ', filename.lower())
            data['normalized_painting'].append(normalized_name)

            # Append the genre
            data['genre'].append(genre)

# Create a DataFrame from the collected data
data_df = pd.DataFrame(data)

# Display the DataFrame
print(data_df.head())
# Out:
#                                             painting  \
# 0                   albert-gleizes_acrobats-1916.jpg
# 1  albert-gleizes_portrait-of-igor-stravinsky-191...
# 2         albert-gleizes_woman-with-animals-1914.jpg
# 3                       georges-braque_a-girl(1).jpg
# 4          georges-braque_bottle-and-fishes-1910.jpg
#
#                                  normalized_painting              genre
# 0                   albert gleizes acrobats 1916 jpg  analytical_cubism
# 1  albert gleizes portrait of igor stravinsky 191...  analytical_cubism
# 2         albert gleizes woman with animals 1914 jpg  analytical_cubism
# 3                       georges braque a girl 1  jpg  analytical_cubism
# 4          georges braque bottle and fishes 1910 jpg  analytical_cubism

# %%
# Save the DataFrame to a CSV file
output_path = '/content/drive/MyDrive/colab_data/painting_data.csv'
data_df.to_csv(output_path, index=False)

print(f"Data saved to {output_path}")
# Out:
# Data saved to /content/drive/MyDrive/colab_data/painting_data.csv

# %%
# Create a regex pattern from the painters_to_keep list
painters_pattern = '|'.join([painter.replace(' ', '.*') for painter in painters_to_keep])

# Filter rows where 'painter' column matches any painter in painters_to_keep
filtered_df = data_df[data_df['normalized_painting'].str.contains(painters_pattern, case=False, na=False)]


# Display the filtered DataFrame
print(filtered_df)
# Out:
#                                                 painting  \
# 3                           georges-braque_a-girl(1).jpg
# 4              georges-braque_bottle-and-fishes-1910.jpg
# 5       georges-braque_castle-at-la-roche-guyon-1909.jpg
# 6      georges-braque_clarinet-and-bottle-of-rum-on-a...
# 7            georges-braque_fruitdish-and-glass-1912.jpg
# ...                                                  ...
# 58691  salvador-dali_vir-et-mulier-in-paradiso-volupt...
# 58692    salvador-dali_proelium-magnum-in-caelo-1967.jpg
# 58693  salvador-dali_planctus-david-in-mortem-saul-19...
# 58694  salvador-dali_rhinocerotic-portrait-of-vermeer...
# 58695    sam-francis_hommage-a-vincent-van-gogh-1989.jpg
#
#                                      normalized_painting  \
# 3                           georges braque a girl 1  jpg
# 4              georges braque bottle and fishes 1910 jpg
# 5       georges braque castle at la roche guyon 1909 jpg
# 6      georges braque clarinet and bottle of rum on a...
# 7            georges braque fruitdish and glass 1912 jpg
# ...                                                  ...
# 58691  salvador dali vir et mulier in paradiso volupt...
# 58692    salvador dali proelium magnum in caelo 1967 jpg
# 58693  salvador dali planctus david in mortem saul 19...
# 58694  salvador dali rhinocerotic portrait of vermeer...
# 58695    sam francis hommage a vincent van gogh 1989 jpg
#
#                         genre
# 3           analytical_cubism
# 4           analytical_cubism
# 5           analytical_cubism
# 6           analytical_cubism
# 7           analytical_cubism
# ...                       ...
# 58691  abstract_expressionism
# 58692  abstract_expressionism
# 58693  abstract_expressionism
# 58694  abstract_expressionism
# 58695  abstract_expressionism
#
# [6561 rows x 3 columns]

# %%
filtered_df.shape
# Out:
# (6561, 3)

# %%
filtered_df.head()
# Out:
#                                             painting  \
# 3                       georges-braque_a-girl(1).jpg
# 4          georges-braque_bottle-and-fishes-1910.jpg
# 5   georges-braque_castle-at-la-roche-guyon-1909.jpg
# 6  georges-braque_clarinet-and-bottle-of-rum-on-a...
# 7        georges-braque_fruitdish-and-glass-1912.jpg
#
#                                  normalized_painting              genre
# 3                       georges braque a girl 1  jpg  analytical_cubism
# 4          georges braque bottle and fishes 1910 jpg  analytical_cubism
# 5   georges braque castle at la roche guyon 1909 jpg  analytical_cubism
# 6  georges braque clarinet and bottle of rum on a...  analytical_cubism
# 7        georges braque fruitdish and glass 1912 jpg  analytical_cubism

# %%
# Define a function to find the painter's name in each row
def find_painter(normalized_name):
    for painter in painters_to_keep:
        if painter.replace(' ', '') in normalized_name.replace(' ', ''):
            return painter
    return None

# %%
# Apply the function to create a 'painter' column
filtered_df['painter'] = filtered_df['normalized_painting'].apply(lambda x: find_painter(x))
# Out:
# <ipython-input-61-bcb1fc46797f>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   filtered_df['painter'] = filtered_df['normalized_painting'].apply(lambda x: find_painter(x))

# %%
filtered_df.head()
# Out:
#                                             painting  \
# 3                       georges-braque_a-girl(1).jpg
# 4          georges-braque_bottle-and-fishes-1910.jpg
# 5   georges-braque_castle-at-la-roche-guyon-1909.jpg
# 6  georges-braque_clarinet-and-bottle-of-rum-on-a...
# 7        georges-braque_fruitdish-and-glass-1912.jpg
#
#                                  normalized_painting              genre  \
# 3                       georges braque a girl 1  jpg  analytical_cubism
# 4          georges braque bottle and fishes 1910 jpg  analytical_cubism
# 5   georges braque castle at la roche guyon 1909 jpg  analytical_cubism
# 6  georges braque clarinet and bottle of rum on a...  analytical_cubism
# 7        georges braque fruitdish and glass 1912 jpg  analytical_cubism
#
#           painter
# 3  georges braque
# 4  georges braque
# 5  georges braque
# 6  georges braque
# 7  georges braque

# %%
filtered_df['painter'].unique()
# Out:
# array(['georges braque', 'pablo picasso', 'paul cezanne', 'rene magritte',
#        'salvador dali', 'pierre auguste renoir', 'claude monet',
#        'vincent van gogh', None], dtype=object)

# %%
filtered_df.shape
# Out:
# (6561, 4)

# %%
# Save the DataFrame to a CSV file
output_path = '/content/drive/MyDrive/colab_data/filtered_data.csv'
filtered_df.to_csv(output_path, index=False)

print(f"Data saved to {output_path}")
# Out:
# Data saved to /content/drive/MyDrive/colab_data/filtered_data.csv

# %% [markdown]
# Before we delete the paintings, we'll count the number of paintings left in the folder.

# %%
# Define the path to your dataset folder
dataset_path = '/content/drive/MyDrive/colab_data/wikiart_dataset'
# Get the list of filenames to keep from 'filtered_df'
filenames_to_keep = set(filtered_df['painting'].tolist())  # Convert to set for faster lookups
delete=[]
# Traverse through the directory structure
for root, _, files in os.walk(dataset_path):
    for filename in files:
      # Check if the file is not in filenames_to_keep
        if filename not in filenames_to_keep:
           file_path = os.path.join(root, filename)  # Use 'root' to get the correct path
           delete.append(file_path)
           #os.remove(file_path)  # Delete the file
           #print(f"Deleted: {file_path}")  # Optional: print deleted files

#print("Files not in filtered_df have been deleted.")

# %%
len(delete)
# Out:
# 52135

# %% [markdown]
# We count the total number of paintings.

# %%
file_count = 0
for root, _, files in os.walk(dataset_path):
    for filename in files:
        # Check if it's a file
        if os.path.isfile(os.path.join(root, filename)):
            file_count += 1

# %%
print(file_count)
# Out:
# 58696

# %%
filtered_df.shape
# Out:
# (6561, 4)

# %% [markdown]
# The numbers mathc so we can delete the paintings.

# %%
# Define the path to your dataset folder
dataset_path = '/content/drive/MyDrive/colab_data/wikiart_dataset'
# Get the list of filenames to keep from 'filtered_df'
filenames_to_keep = set(filtered_df['painting'].tolist())  # Convert to set for faster lookups
delete=[]
# Traverse through the directory structure
for root, _, files in os.walk(dataset_path):
    for filename in files:
      # Check if the file is not in filenames_to_keep
        if filename not in filenames_to_keep:
           file_path = os.path.join(root, filename)  # Use 'root' to get the correct path
           os.remove(file_path)  # Delete the file
           print(f"Deleted: {file_path}")  # Optional: print deleted files

print("Files not in filtered_df have been deleted.")
# Out:
# Streaming output truncated to the last 5000 lines.
# Deleted: /content/drive/MyDrive/colab_data/wikiart_dataset/Realism/isaac-levitan_stormy-day-1897.jpg
# Deleted: /content/drive/MyDrive/colab_data/wikiart_dataset/Realism/isaac-levitan_street-in-yalta-1886.jpg
# Deleted: /content/drive/MyDrive/colab_data/wikiart_dataset/Realism/isaac-levitan_stubbled-field.jpg
# Deleted: /content/drive/MyDrive/colab_data/wikiart_dataset/Realism/isaac-levitan_study-to-above-the-eternal-tranquility-1892.jpg
# Deleted: /content/drive/MyDrive/colab_data/wikiart_dataset/Realism/isaac-levitan_summer-evening-edge-of-village-1899.jpg
# Deleted: /content/drive/MyDrive/colab_data/wikiart_dataset/Realism/isaac-levitan_summer-evening-river.jpg
# Deleted: /content/drive/MyDrive/colab_data/wikiart_dataset/Realism/isaac-levitan_summer-evening.jpg
# Deleted: /content/drive/MyDrive/colab_data/wikiart_dataset/Realism/isaac-levitan_sunny-autumn-day-1897.jpg
# Deleted: /content/drive/MyDrive/colab_data/wikiart_dataset/Realism/isaac-levitan_sunny-day-1876.jpg
# Deleted: /content/drive/MyDrive/colab_data/wikiart_dataset/Realism/isaac-levitan_sunny-day-1898.jpg
# Deleted: /content/drive/MyDrive/colab_data/wikiart_dataset/Realism/isaac-levitan_sunny-day-a-village-1898.jpg
# Deleted: /content/drive/MyDrive/colab_data/wikiart_dataset/Realism/isaac-levitan_sunny-day-near-the-isba-1899.jpg
# Deleted: /content/drive/MyDrive/colab_data/wikiart_dataset/Realism/isaac-levitan_sunset-forest-edge-1900.jpg
# Deleted: /content/drive/MyDrive/colab_data/wikiart_dataset/Realism/isaac-levitan_sunset-over-a-forest-lake-study.jpg
# Deleted: /content/drive/MyDrive/colab_data/wikiart_dataset/Realism/isaac-levitan_tatarian-cemetery-crimea-1886.jpg
# Deleted: /content/drive/MyDrive/colab_data/wikiart_dataset/Realism/isaac-levitan_tempest-rain-1899.jpg
# Deleted: /content/drive/MyDrive/colab_data/wikiart_dataset/Realism/isaac-levitan_the-evening-after-the-rain-1879.jpg
# Deleted: /content/drive/MyDrive/colab_data/wikiart_dataset/Realism/isaac-levitan_the-first-green-may-1888.jpg
# Deleted: /content/drive/MyDrive/colab_data/wikiart_dataset/Realism/isaac-levitan_the-gully-1898.jpg
# Deleted: /content/drive/MyDrive/colab_data/wikiart_dataset/Realism/isaac-levitan_the-halt.jpg
# Deleted: /content/drive/MyDrive/colab_data/wikiart_dataset/Realism/isaac-levitan_the-istra-river-1886.jpg
# Deleted: /content/drive/MyDrive/colab_data/wikiart_dataset/Realism/isaac-levitan_the-lake-1898.jpg
# Deleted: /content/drive/MyDrive/colab_data/wikiart_dataset/Realism/isaac-levitan_the-lake-barns-at-the-edge-of-forest-1899.jpg
# Deleted: /content/drive/MyDrive/colab_data/wikiart_dataset/Realism/isaac-levitan_the-lake-eventide.jpg
# Deleted: /content/drive/MyDrive/colab_data/wikiart_dataset/Realism/isaac-levitan_the-lake.jpg
# Deleted: /content/drive/MyDrive/colab_data/wikiart_dataset/Realism/isaac-levitan_the-last-rays-of-the-sun-1899.jpg
# Deleted: /content/drive/MyDrive/colab_data/wikiart_dataset/Realism/isaac-levitan_the-last-rays-of-the-sun-a-lake-1899.jpg
# Deleted: /content/drive/MyDrive/colab_data/wikiart_dataset/Realism/isaac-levitan_the-last-rays-of-the-sun-aspen-forest-1897.jpg
# Deleted: /content/drive/MyDrive/colab_data/wikiart_dataset/Realism/isaac-levitan_the-last-snow-village-savvinskaya-1884.jpg
# Deleted: /content/drive/MyDrive/colab_data/wikiart_dataset/Realism/isaac-levitan_the-trunk-of-an-old-tree-1883.jpg
# Deleted: /content/drive/MyDrive/colab_data/wikiart_dataset/Realism/isaac-levitan_the-twilight-moon-1898.jpg
# Deleted: /content/drive/MyDrive/colab_data/wikiart_dataset/Realism/isaac-levitan_the-vladimir-s-road-1892-1.jpg
# Deleted: /content/drive/MyDrive/colab_data/wikiart_dataset/Realism/isaac-levitan_the-vladimir-s-road-1892.jpg
# Deleted: /content/drive/MyDrive/colab_data/wikiart_dataset/Realism/isaac-levitan_three-pines-1886.jpg
# Deleted: /content/drive/MyDrive/colab_data/wikiart_dataset/Realism/isaac-levitan_trail-in-the-forest.jpg
# Deleted: /content/drive/MyDrive/colab_data/wikiart_dataset/Realism/isaac-levitan_trail.jpg
# Deleted: /content/drive/MyDrive/colab_data/wikiart_dataset/Realism/isaac-levitan_train-on-the-way.jpg
# Deleted: /content/drive/MyDrive/colab_data/wikiart_dataset/Realism/isaac-levitan_trees-and-bushes.jpg
# Deleted: /content/drive/MyDrive/colab_data/wikiart_dataset/Realism/isaac-levitan_trunk-of-burgeoning-oak.jpg
# Deleted: /content/drive/MyDrive/colab_data/wikiart_dataset/Realism/isaac-levitan_trunks-of-the-trees.jpg
# Deleted: /content/drive/MyDrive/colab_data/wikiart_dataset/Realism/isaac-levitan_twilight-1900.jpg
# Deleted: /content/drive/MyDrive/colab_data/wikiart_dataset/Realism/isaac-levitan_twilight-a-castle-1898.jpg
# Deleted: /content/drive/MyDrive/colab_data/wikiart_dataset/Realism/isaac-levitan_twilight-moon-1899-1.jpg
# Deleted: /content/drive/MyDrive/colab_data/wikiart_dataset/Realism/isaac-levitan_twilight-moon-1899.jpg
# Deleted: /content/drive/MyDrive/colab_data/wikiart_dataset/Realism/isaac-levitan_twilight-stacks-1899.jpg
# Deleted: /content/drive/MyDrive/colab_data/wikiart_dataset/Realism/isaac-levitan_valley-of-the-river-autumn-1896.jpg
# Deleted: /content/drive/MyDrive/colab_data/wikiart_dataset/Realism/isaac-levitan_venice-1890.jpg
# Deleted: /content/drive/MyDrive/colab_data/wikiart_dataset/Realism/isaac-levitan_vesper-chimes-1892.jpg
# Deleted: /content/drive/MyDrive/colab_data/wikiart_dataset/Realism/isaac-levitan_view-in-plyos-1888.jpg
# Deleted: /content/drive/MyDrive/colab_data/wikiart_dataset/Realism/isaac-levitan_view-of-nizhniy-novgorod.jpg
# Deleted: /content/drive/MyDrive/colab_data/wikiart_dataset/Realism/isaac-levitan_view-of-novodevichy-monastery-1899.jpg
# Deleted: /content/drive/MyDrive/colab_data/wikiart_dataset/Realism/isaac-levitan_view-of-volga-from-the-high-bank-1887.jpg
# Deleted: /content/drive/MyDrive/colab_data/wikiart_dataset/Realism/isaac-levitan_village-1884.jpg
# Deleted: /content/drive/MyDrive/colab_data/wikiart_dataset/Realism/isaac-levitan_village-1888.jpg
# Deleted: /content/drive/MyDrive/colab_data/wikiart_dataset/Realism/isaac-levitan_village-a-gray-day.jpg
# Deleted: /content/drive/MyDrive/colab_data/wikiart_dataset/Realism/isaac-levitan_village-at-the-edge-of-forest-1.jpg
# Deleted: /content/drive/MyDrive/colab_data/wikiart_dataset/Realism/isaac-levitan_village-at-the-edge-of-forest.jpg
# Deleted: /content/drive/MyDrive/colab_data/wikiart_dataset/Realism/isaac-levitan_village-at-the-riverbank-1883.jpg
# Deleted: /content/drive/MyDrive/colab_data/wikiart_dataset/Realism/isaac-levitan_village-by-the-ravine.jpg
# Deleted: /content/drive/MyDrive/colab_data/wikiart_dataset/Realism/isaac-levitan_village-early-spring-1888.jpg
# Deleted: /content/drive/MyDrive/colab_data/wikiart_dataset/Realism/isaac-levitan_village-in-winter.jpg
# Deleted: /content/drive/MyDrive/colab_data/wikiart_dataset/Realism/isaac-levitan_village-khotkovo.jpg
# Deleted: /content/drive/MyDrive/colab_data/wikiart_dataset/Realism/isaac-levitan_village-savvinskaya-1884.jpg
# Deleted: /content/drive/MyDrive/colab_data/wikiart_dataset/Realism/isaac-levitan_village-savvinskaya-near-zvenigorod-1884-1.jpg
# Deleted: /content/drive/MyDrive/colab_data/wikiart_dataset/Realism/isaac-levitan_village-savvinskaya-near-zvenigorod-1884-2.jpg
# Deleted: /content/drive/MyDrive/colab_data/wikiart_dataset/Realism/isaac-levitan_village-savvinskaya-near-zvenigorod-1884.jpg
# Deleted: /content/drive/MyDrive/colab_data/wikiart_dataset/Realism/isaac-levitan_village-savvinskaya-near-zvenigorod-at-summer-1884.jpg
# Deleted: /content/drive/MyDrive/colab_data/wikiart_dataset/Realism/isaac-levitan_village-twilight-1897.jpg
# Deleted: /content/drive/MyDrive/colab_data/wikiart_dataset/Realism/isaac-levitan_village-windmill.jpg
# Deleted: /content/drive/MyDrive/colab_data/wikiart_dataset/Realism/isaac-levitan_village-winter-1888.jpg
# Deleted: /content/drive/MyDrive/colab_data/wikiart_dataset/Realism/isaac-levitan_village.jpg
# Deleted: /content/drive/MyDrive/colab_data/wikiart_dataset/Realism/isaac-levitan_volga-1889.jpg
# Deleted: /content/drive/MyDrive/colab_data/wikiart_dataset/Realism/isaac-levitan_volga-a-calm-day-1895.jpg
# Deleted: /content/drive/MyDrive/colab_data/wikiart_dataset/Realism/isaac-levitan_volga-barges.jpg
# Deleted: /content/drive/MyDrive/colab_data/wikiart_dataset/Realism/isaac-levitan_wassylsursk-1887.jpg
# Deleted: /content/drive/MyDrive/colab_data/wikiart_dataset/Realism/isaac-levitan_water-lilies-nenuphar-1895.jpg
# Deleted: /content/drive/MyDrive/colab_data/wikiart_dataset/Realism/isaac-levitan_water-margin-a-pond.jpg
# Deleted: /content/drive/MyDrive/colab_data/wikiart_dataset/Realism/isaac-levitan_watermill.jpg
# Deleted: /content/drive/MyDrive/colab_data/wikiart_dataset/Realism/isaac-levitan_white-lilac-1895.jpg
# Deleted: /content/drive/MyDrive/colab_data/wikiart_dataset/Realism/isaac-levitan_widely.jpg
# Deleted: /content/drive/MyDrive/colab_data/wikiart_dataset/Realism/isaac-levitan_windy-day.jpg
# Deleted: /content/drive/MyDrive/colab_data/wikiart_dataset/Realism/isaac-levitan_winter-1895.jpg
# Deleted: /content/drive/MyDrive/colab_data/wikiart_dataset/Realism/isaac-levitan_winter-landscape-cemetery.jpg
# Deleted: /content/drive/MyDrive/colab_data/wikiart_dataset/Realism/isaac-levitan_winter-landscape-with-mill-1884.jpg
# Deleted: /content/drive/MyDrive/colab_data/wikiart_dataset/Realism/isaac-levitan_winter-path-in-the-forest.jpg
# Deleted: /content/drive/MyDrive/colab_data/wikiart_dataset/Realism/isaac-levitan_wooded-riverbank-twilight-1892.jpg
# Deleted: /content/drive/MyDrive/colab_data/wikiart_dataset/Realism/isaac-levitan_yurievets-gloomy-day-on-the-volga-1890.jpg
# Deleted: /content/drive/MyDrive/colab_data/wikiart_dataset/Realism/istvan-nagy_soldier-head-1915.jpg
# Deleted: /content/drive/MyDrive/colab_data/wikiart_dataset/Realism/ivan-grohar_brna-1899.jpg
# Deleted: /content/drive/MyDrive/colab_data/wikiart_dataset/Realism/ivan-kramskoy_a-girl-with-her-scythe-1873.jpg
# Deleted: /content/drive/MyDrive/colab_data/wikiart_dataset/Realism/ivan-kramskoy_actor-alexander-lensky-pavlovich-as-petruchio-inshakespeare-s-taming-of-the-shrew-1883.jpg
# Deleted: /content/drive/MyDrive/colab_data/wikiart_dataset/Realism/ivan-kramskoy